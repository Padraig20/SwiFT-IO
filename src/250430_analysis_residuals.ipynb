# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# check residuals component

residual_path = Path("/pscratch/sd/k/kimbo/SwiFT-IO/analysis/3_preds_plot/tubg3tim/residuals_test.npy")
res_dict = np.load(residual_path, allow_pickle=True).item()

print('keys of res_dict', res_dict.keys())

emotion_labels = ['Anger', 'Happy', 'Fear', 'Sad', 'Excited', 'Positive', 'Negative']
# Out:
# keys of res_dict dict_keys(['split', 'subject', 'start_frame', 'end_frame', 'residual_0_Anger', 'prediction_0_Anger', 'residual_1_Happy', 'prediction_1_Happy', 'residual_2_Fear', 'prediction_2_Fear', 'residual_3_Sad', 'prediction_3_Sad', 'residual_4_Excited', 'prediction_4_Excited', 'residual_5_Positive', 'prediction_5_Positive', 'residual_6_Negative', 'prediction_6_Negative'])
